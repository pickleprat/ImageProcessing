# %%
from skimage import data, io
import matplotlib.pyplot as plt 
import cv2 
# %matplotlib inline

# %%
img = io.imread('static/fariii_prettyyy.jpg')
img_red = img[:, :, 2]
plt.figure(figsize=(12,19))
plt.imshow(img)

# %%
img.shape
# Out:
# (2340, 1080, 3)

# %%
plt.imshow(cv2.resize(img, (1965, 3800))) 
plt.savefig('prettier_fari.jpg')
